# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/raw/michigan_housing.csv")

print(df.head())

plt.plot(df["date"], df["median_price"])
plt.xticks(rotation=45)
plt.title("Michigan Median Housing Prices")
plt.show()
